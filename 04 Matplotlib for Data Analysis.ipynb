# %% [markdown]
# ___
# <a href='http://www.kgptalkie.com'><img src='kgptalkie_strips.png'/></a>
# ___
#
# <center><em>Copyright by KGPTalkie</em></center>
# <center><em>For free ML tutorials, visit us at <a href='http://www.kgptalkie.com'>www.kgptalkie.com</a></em></center>

# %% [markdown]
# # Matplotlib for Data Analysis

# %% [markdown]
# https://matplotlib.org/

# %% [markdown]
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Line Plot

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from numpy.random import randint

# %matplotlib inline

# %%
x = np.linspace(1,10, 20)
y = randint(1,50, 20)

# %%
x.size, y.size
# Out:
# (20, 20)

# %%
# help(plt)

plt.plot(x, y)

# plt.figure()
# plt.plot(y, x)

plt.show()

# %% [markdown]
# #### IMDB Movie Data Analysis

# %%
movies = pd.read_csv('data/IMDB-Movie-Data.csv', nrows=50)
movies.head()
movies.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
movies.fillna(0, inplace=True)

# %%
plt.figure(figsize=(10,6))
plt.plot( movies['Rank'], movies['Revenue (Millions)'])
plt.show()

# %%
idx = movies['Revenue (Millions)'].idxmax()
movies.iloc[idx]
# Out:
# Rank                                                                 13
# Title                                                         Rogue One
# Genre                                           Action,Adventure,Sci-Fi
# Description           The Rebel Alliance makes a risky move to steal...
# Director                                                 Gareth Edwards
# Actors                Felicity Jones, Diego Luna, Alan Tudyk, Donnie...
# Year                                                               2016
# Runtime (Minutes)                                                   133
# Rating                                                              7.9
# Votes                                                            323118
# Revenue (Millions)                                               532.17
# Metascore                                                          65.0
# Name: 12, dtype: object

# %%
movies.isnull().sum()
# Out:
# Rank                  0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    7
# Metascore             6
# dtype: int64

# %%
# plot rank vs runtime
movies.head(1)

plt.figure(figsize=(10,3))
# plt.plot(movies['Rank'], movies['Runtime (Minutes)'])
# plt.plot(movies['Rank'], movies['Votes'])

plt.plot(movies['Rank'], movies['Metascore'])

# %% [markdown]
# #### Line Styling and Putting Labels

# %%
plt.figure(figsize=(10,3))
plt.plot(movies['Rank'], movies['Rating'], color='r', linestyle='--',
             linewidth=2, marker='o', markersize=10, markerfacecolor='y',
            markeredgecolor='b', markeredgewidth=1)
plt.xlabel('Rank')
plt.ylabel('Rating')
a = plt.title('Rank vs Rating')

# %% [markdown]
# #### Scatter, Bar, and Histogram Plot

# %%
plt.figure(figsize=(10,3))
plt.scatter(movies['Rank'], movies['Rating'], color='y', marker='*', s=100)

plt.figure(figsize=(10,3))
plt.bar(movies['Rank'], movies['Rating'], color='r', width=0.9)
plt.plot(movies['Rank'], movies['Rating'], color='g', linestyle='--',
             linewidth=2, marker='o', markersize=10, markerfacecolor='y',
            markeredgecolor='b', markeredgewidth=1)


plt.figure(figsize=(3,10))
plt.barh(movies['Rank'], movies['Rating'], color='r')


plt.figure(figsize=(10,3))
plt.hist(movies['Rating'], bins=20, color='r', alpha=0.5)


plt.figure(figsize=(3, 10))
plt.hist(movies['Rating'], bins=20, color='r', alpha=0.5, 
         orientation='horizontal')

plt.figure(figsize=(10, 3))
plt.boxplot(movies['Rating'], patch_artist=True)

plt.show()

# %% [markdown]
# #### Subplot

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
movies.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
plt.figure(figsize=(9,6))
plt.subplot(1,3,1)
plt.barh(movies['Rank'], movies['Rating'], color='r')

plt.subplot(1,3,2)
plt.hist(movies['Rating'], bins=20, color='r', alpha=0.9, 
         orientation='horizontal')

plt.subplot(1,3,3)
plt.hist(movies['Votes'], bins=20, color='r', alpha=0.9, 
         orientation='horizontal')

plt.show()
plt.tight_layout()

# %%
# 2x2 subplot
plt.figure(figsize=(8,6))
# 1------------------
plt.subplot(2,2, 1)
plt.plot(movies['Rank'], movies['Rating'], color='g', linestyle='--',
             linewidth=2, marker='o', markersize=10, markerfacecolor='y',
            markeredgecolor='b', markeredgewidth=1)

plt.xlabel('Rank')
plt.ylabel('Rating')
plt.title('Rank vs Rating')

# 2-----------
plt.subplot(2,2, 2)
plt.plot(movies['Rank'], movies['Revenue (Millions)'], color='b', linestyle='--',
             linewidth=2, marker='o', markersize=10, markerfacecolor='r',
            markeredgecolor='b', markeredgewidth=1)

plt.xlabel('Rank')
plt.ylabel('Revenue (Millions)')
plt.title('Rank vs Revenue (Millions)')

# 3-----------
plt.subplot(2,2, 3)
plt.plot(movies['Rank'], movies['Metascore'], color='k', linestyle='--',
             linewidth=2, marker='o', markersize=10, markerfacecolor='y',
            markeredgecolor='b', markeredgewidth=1)

plt.xlabel('Rank')
plt.ylabel('Metascore')
plt.title('Rank vs Metascore')

# 4-----------
plt.subplot(2,2, 4)
plt.plot(movies['Rank'], movies['Votes'], color='y', linestyle='--',
             linewidth=2, marker='o', markersize=10, markerfacecolor='b',
            markeredgecolor='y', markeredgewidth=1)

plt.xlabel('Rank')
plt.ylabel('Votes')
plt.title('Rank vs Votes')


plt.tight_layout()

# %% [markdown]
# #### Subplots

# %%
# 2x2 subplots
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(8,6))

ax[0][0].plot(movies['Rank'], movies['Rating'], color='g', linestyle='--',
             linewidth=2, marker='o', markersize=10, markerfacecolor='y',
            markeredgecolor='b', markeredgewidth=1)

ax[0][0].set_xlabel('Rank')
ax[0][0].set_ylabel('Rating')
ax[0][0].set_title('Rank vs Rating')


ax[1][1].plot(movies['Rank'], movies['Votes'], color='g', linestyle='--',
             linewidth=2, marker='o', markersize=10, markerfacecolor='y',
            markeredgecolor='b', markeredgewidth=1)

ax[1][1].set_xlabel('Rank')
ax[1][1].set_ylabel('Votes')
ax[1][1].set_title('Rank vs Votes')

plt.tight_layout()

# %% [markdown]
# #### Creating a Zoomed Sub-Figure of a Figure

# %%
fig = plt.figure(figsize=(10,3))
ax1 = fig.add_axes([0,0, 1, 1])
ax2 = fig.add_axes([0.1,0.15, 0.2, 0.30])

ax1.plot(movies['Rank'], movies['Rating'], color='g', linestyle='--',
             linewidth=2, marker='o', markersize=10, markerfacecolor='y',
            markeredgecolor='b', markeredgewidth=1)

ax1.set_xlabel('Rank')
ax1.set_ylabel('Rating')
ax1.set_title('Rank vs Rating')

### plot zoomed subplots
ax2.plot(movies['Rank'], movies['Rating'], color='g', linestyle='--',
             linewidth=2, marker='o', markersize=10, markerfacecolor='y',
            markeredgecolor='b', markeredgewidth=1)
ax2.set_xlim(20,25)
ax2.set_ylim(4,9)
ax2.set_xlabel('Rank')
ax2.set_ylabel('Rating')
ax2.set_title('Rank vs Rating (Zoomed)')

plt.show()

# %% [markdown]
# #### xlim and ylim, legend, grid, xticks, yticks

# %%
plt.figure(figsize=(10,3))
plt.plot(movies['Rank'], movies['Rating'], linestyle='--',
        color='r', label='Rating')

plt.plot(movies['Rank'], movies['Rating']+1, linestyle='--',
        color='g', label='Rating + 1')

plt.xlim(0,30)
plt.ylim(4,10)
plt.xlabel('Rank')
plt.ylabel('Rating')
plt.title('Rank vs Rating')
plt.legend()

plt.grid()

plt.xticks(np.arange(0,30, 4))
plt.yticks(np.arange(4,10, 1))

plt.show()

# %% [markdown]
# #### Pie Chart

# %%
df = pd.read_csv('data/quarters.csv', nrows=5)

plt.figure(figsize=(4,4))
plt.pie(df['Q1'], labels=df['Salesman'], autopct='%1.1f%%',
       shadow=True, startangle=180, explode= (0,0,0,0.05,0))

plt.title('Revenue by Querters')


plt.savefig('data/piechart.png', dpi=300)
plt.show()

# %% [markdown]
# # Other Resources
# |  ML Course | Description |
# |:---|:---|
# | [**Data Visualization in Python Masterclass™: Beginners to Pro**](https://bit.ly/udemy95off_kgptalkie) |  Learn to build Machine Learning and Deep Learning models using Python and its libraries like Scikit-Learn, Keras, and TensorFlow. |
# | [**Python for Machine Learning: A Step-by-Step Guide**](https://bit.ly/ml-ds-project) | Learn to build Machine Learning and Deep Learning models using Python and its libraries like Scikit-Learn, Keras, and TensorFlow. |
# | [**Python for Linear Regression in Machine Learning**](https://bit.ly/regression-python) | Learn to build Linear Regression models using Python and its libraries like Scikit-Learn. |
# | [**Introduction to Spacy 3 for Natural Language Processing**](https://bit.ly/spacy-intro) | Learn to build Natural Language Processing models using Python and its libraries like Spacy. |
# | [**Advanced Machine Learning and Deep Learning Projects**](https://bit.ly/kgptalkie_ml_projects) | Learn to build Advanced Machine Learning and Deep Learning models using Python and transformer models like BERT, GPT-2, and XLNet. |
# | [**Natural Language Processing in Python for Beginners**](https://bit.ly/intro_nlp) | Learn to build Natural Language Processing Projects using Spacy, NLTK, and Gensim, and transformer models like BERT, GPT-2, and XLNet. |
# | [**Deployment of Machine Learning Models in Production in Python**](https://bit.ly/bert_nlp) |  Learn to deploy Machine Learning and Deep Learning models using Python and its libraries like Flask, Streamlit, and NGINX. |
# | [**R 4.0 Programming for Data Science - Beginners to Pro**](https://bit.ly/r4-ml) | Learn to build Machine Learning and Deep Learning models using R and its libraries like caret, tidyverse, and keras. |
